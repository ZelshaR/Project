# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

#dfv = pd.read_csv('https://raw.githubusercontent.com/ZelshaR/Project/main/NoteBooks/CSVs/dfv.csv')

Norm = pd.read_csv('https://raw.githubusercontent.com/ZelshaR/Project/main/NoteBooks/CSVs/newdfc.csv')
Norm.index = Norm['Unnamed: 0'].values
del Norm['Unnamed: 0']

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['nam'] = 0
for i in range(len(df)):
    df['nam'][i] = (dt.date(2020,df['date'][i].month,df['date'][i].day) - dt.date(2020,1,1)).days
for i in range(len(df)):
    if df['date'].iloc[i].year == 2021:
        df['nam'].iloc[i] = df['nam'].iloc[i]+365
    elif df['date'].iloc[i].year == 2022:
        df['nam'].iloc[i] = df['nam'].iloc[i]+730
# Out:
# <ipython-input-109-4af1d23511bc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nam'][i] = (dt.date(2020,df['date'][i].month,df['date'][i].day) - dt.date(2020,1,1)).days
# C:\Users\user01\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
dfc = pd.DataFrame(columns = df['location'].unique(), index = list(range(1,max(df['nam'] + 1))))
dfc = dfv.fillna(0)

dfd = pd.DataFrame(columns = df['location'].unique(), index = list(range(1,max(df['nam'] + 1))))
dfd = dfv.fillna(0)

# %%
for i in range(len(df)):
    dfc[df['location'][i]][df['nam'][i]]=df['new_cases'][i]
for i in range(len(df)):
    dfd[df['location'][i]][df['nam'][i]]=df['new_deaths'][i]
# Out:
# <ipython-input-111-490f3d27e1fb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[df['location'][i]][df['nam'][i]]=df['new_cases'][i]
# <ipython-input-111-490f3d27e1fb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfd[df['location'][i]][df['nam'][i]]=df['new_deaths'][i]

# %%
a = Norm.columns
b = dfc.columns
c = list(set(b) - set(a))

# %%
for i in c:
    del dfd[i]
    del dfc[i]

# %%
dfc
# Out:
#      Afghanistan  Africa  Albania  Algeria  Angola  Argentina  Armenia  \
# 1              0       0      0.0        0       0        NaN        0
# 2              0       0      0.0        0       0        NaN        0
# 3              0       0      0.0        0       0        NaN        0
# 4              0       0      0.0        0       0        NaN        0
# 5              0       0      0.0        0       0        NaN        0
# ..           ...     ...      ...      ...     ...        ...      ...
# 765          353   20558      0.0      792      11    21836.0     4032
# 766          480   14863   1452.0      378      13    12664.0     2467
# 767          733   13575    251.0      502      45    25406.0     1631
# 768          815   15133    841.0      610      15    32790.0     2486
# 769          811   19268    700.0      585      29    27252.0     2811
#
#        Asia  Australia  Austria  ...  United Arab Emirates  United Kingdom  \
# 1         0          0        0  ...                     0             0.0
# 2         0          0        0  ...                     0             0.0
# 3         0          0        0  ...                     0             0.0
# 4         0          0        0  ...                     0             0.0
# 5         0          0        0  ...                     0             0.0
# ..      ...        ...      ...  ...                   ...             ...
# 765  577587      22985    32258  ...                  1991         60114.0
# 766  583347      25247    29324  ...                  2015         53326.0
# 767  563095      27373    27299  ...                  1704         64322.0
# 768  633995      31510    27087  ...                  1615         66634.0
# 769  590118      11483    38309  ...                  1538         67677.0
#
#      United States  Upper middle income  Uruguay  Uzbekistan  Venezuela  \
# 1              0.0                    0        0           0          0
# 2              0.0                    0        0           0          0
# 3              0.0                    0        0           0          0
# 4              0.0                    0        0           0          0
# 5              0.0                    0        0           0          0
# ..             ...                  ...      ...         ...        ...
# 765       104104.0               693376     9074         912       2157
# 766        80051.0               529187     6094         887       1448
# 767       336568.0               528556     6968         832          0
# 768       221262.0               721705     8444         773       1694
# 769       187299.0               745423     8100         778       1560
#
#        World  Zambia  Zimbabwe
# 1          0       0         0
# 2          0       0         0
# 3          0       0         0
# 4          0       0         0
# 5          0       0         0
# ..       ...     ...       ...
# 765  2095519       0       232
# 766  1833762     429         0
# 767  2235580     111         0
# 768  3129028     319       201
# 769  2401537     414       137
#
# [769 rows x 129 columns]

# %%
for h in dfd.columns:    
    for i in range(len(dfd)):
        if dfd[h].iloc[i] < 0:
            dfd[h].iloc[i] = 0
for h in dfc.columns:    
    for i in range(len(dfc)):
        if dfc[h].iloc[i] < 0:
            dfc[h].iloc[i] = 0
# Out:
# C:\Users\user01\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
dfc = dfc.drop(labels = [424],axis = 0)
dfd = dfd.drop(labels = [424],axis = 0)

# %%
dfc = dfc.fillna(0)
dfd = dfd.fillna(0)

# %%
dfc.to_csv('newdfc.csv')
dfd.to_csv('newdfd.csv')

# %%
corlist = dfc.columns
dfcsr = dfc.copy(deep=True)
dfdsr = dfd.copy(deep=True)
for i in corlist:
    for j in range(len(dfcsr)):
        dfcsr[i].iloc[j] = (dfc[i].iloc[j]-min(dfc[i]))/(max(dfc[i])-min(dfc[i]))
for i in corlist:
    for j in range(len(dfdsr)):
        dfdsr[i].iloc[j] = (dfd[i].iloc[j]-min(dfd[i]))/(max(dfd[i])-min(dfd[i]))

# %%
dfcsr.to_csv('newdfcsr.csv')
dfdsr.to_csv('newdfdsr.csv')

# %%
df
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 160694      ZWE    Africa     Zimbabwe 2022-02-05     230402.0      232.0
# 160695      ZWE    Africa     Zimbabwe 2022-02-06     230402.0        0.0
# 160696      ZWE    Africa     Zimbabwe 2022-02-07     230402.0        0.0
# 160697      ZWE    Africa     Zimbabwe 2022-02-08     230603.0      201.0
# 160698      ZWE    Africa     Zimbabwe 2022-02-09     230740.0      137.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 160694             141.000        5362.0         5.0                4.143
# 160695             134.571        5362.0         0.0                3.571
# 160696             105.143        5362.0         0.0                3.429
# 160697             107.429        5366.0         4.0                2.286
# 160698             104.000        5367.0         1.0                2.143
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 160694  ...          30.7                  36.791                         1.7
# 160695  ...          30.7                  36.791                         1.7
# 160696  ...          30.7                  36.791                         1.7
# 160697  ...          30.7                  36.791                         1.7
# 160698  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  \
# 0                 64.83                    0.511
# 1                 64.83                    0.511
# 2                 64.83                    0.511
# 3                 64.83                    0.511
# 4                 64.83                    0.511
# ...                 ...                      ...
# 160694            61.49                    0.571
# 160695            61.49                    0.571
# 160696            61.49                    0.571
# 160697            61.49                    0.571
# 160698            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 160694                                   NaN                          NaN
# 160695                                   NaN                          NaN
# 160696                                   NaN                          NaN
# 160697                                   NaN                          NaN
# 160698                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million  nam
# 0                    NaN                                      NaN   54
# 1                    NaN                                      NaN   55
# 2                    NaN                                      NaN   56
# 3                    NaN                                      NaN   57
# 4                    NaN                                      NaN   58
# ...                  ...                                      ...  ...
# 160694               NaN                                      NaN  765
# 160695               NaN                                      NaN  766
# 160696               NaN                                      NaN  767
# 160697               NaN                                      NaN  768
# 160698               NaN                                      NaN  769
#
# [160699 rows x 68 columns]
